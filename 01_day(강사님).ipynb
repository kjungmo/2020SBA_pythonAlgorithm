# %%
a = 123
a = -178
a = 0

# %%
a = 1.2
a = -3.45

# %%
a = 4.24E10
a = 4.24e-10

# %%
a = 1234
a = 0o177
a = 0x8ff
a = 0xabc

# %%
a = 3
b = 4
a+b
# Out:
# 7

# %%
a*b
# Out:
# 12

# %%
a/b
# Out:
# 0.75

# %%
a//b
# Out:
# 0

# %%
a%b
# Out:
# 3

# %%
a ** b
# Out:
# 81

# %%
"Life is too short, You need Python"
"a"
"123"
# Out:
# '123'

# %%
"Python's favorite food is perl"
# Out:
# "Python's favorite food is perl"

# %%
'Python\'s favorite food is perl'
# Out:
# "Python's favorite food is perl"

# %%
"Life is too short\nYou need Python"
# Out:
# 'Life is too short\nYou need Python'

# %%
'''Life is too short
You need Python'''
# Out:
# 'Life is too short\nYou need Python'

# %%
head = "python"
tail = " is fun!"
head + tail
# Out:
# 'python is fun!'

# %%
a = "python"
a * 2
# Out:
# 'pythonpython'

# %%
print("="*10)
print("My Program")
print("="*10)
# Out:
# ==========
# My Program
# ==========

# %%
len("hello")
# Out:
# 5

# %%
a = "Life is too short, You need Python"

# %%
a[3]
# Out:
# 'e'

# %%
a[0]
# Out:
# 'L'

# %%
a[12]
# Out:
# 's'

# %%
a[-1]
# Out:
# 'n'

# %%
a[-2]
# Out:
# 'o'

# %%
b = a[0]+a[1]+a[2]+a[3]
b
# Out:
# 'Life'

# %%
b = a[0:4]
b
# Out:
# 'Life'

# %%
b = a[0:5]
b
# Out:
# 'Life '

# %%
b = a[12:17]
b
# Out:
# 'short'

# %%
b = a[19:]
b
# Out:
# 'You need Python'

# %%
b = a[:17]
b
# Out:
# 'Life is too short'

# %%
b = a[:]
a
# Out:
# 'Life is too short, You need Python'

# %%
b = a[19:-7]
b
# Out:
# 'You need'

# %%
a = "20010331Rainy"
date = a[:8]
weather = a[8:]
print(date)
print(weather)
# Out:
# 20010331
# Rainy

# %%
a = "20010331Rainy"
year = a[:4]
date = a[4:8]
weather = a[8:]
print(year)
print(date)
print(weather)
# Out:
# 2001
# 0331
# Rainy

# %%
a = "pithon"
a[1]='y'
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-9be10ab68dc9> in <module>
#       1 a = "pithon"
# ----> 2 a[1]='y'
#       3 a
#
# TypeError: 'str' object does not support item assignment

# %%
a = "pithon"
b = a[:1]+'y'+a[2:]
b
# Out:
# 'python'

# %%
"I eat %d apples." % 3
# Out:
# 'I eat 3 apples.'

# %%
"I eat %s apples." % "five"
# Out:
# 'I eat five apples.'

# %%
number = 3
"I eat %d apples." % number
# Out:
# 'I eat 3 apples.'

# %%
number = 10
day = "three"
"I ate %d apples. so I was sick for %s days." %(number, day)
# Out:
# 'I ate 10 apples. so I was sick for three days.'

# %%
"I have %s apples" % 3
# Out:
# 'I have 3 apples'

# %%
"rate is %s" % 3.234
# Out:
# 'rate is 3.234'

# %%
"Error is %d%%" % 98
# Out:
# 'Error is 98%'

# %%
"[%10s]" % "hi"
# Out:
# '[        hi]'

# %%
"[%-10s]" % "hi"
# Out:
# '[hi        ]'

# %%
"%f" % 3.42134274
# Out:
# '3.421343'

# %%
"%0.4f" % 3.42137274
# Out:
# '3.4214'

# %%
"%10.4f" % 3.42137274
# Out:
# '    3.4214'

# %%
"%-10.4f" % 3.42137274
# Out:
# '3.4214    '
